# %%
a=10
if(a>5):
  print("10 is greater than 5")
# Out:
# 10 is greater than 5

# %%
day="tuesday"
if(day=="saturday"):
  print("colour")
else:
  print("uniform")
# Out:
# uniform

# %%
a=10
b=15
if(a>b):
  print("a is greater than b")
else:
  print("b is greater than a")
# Out:
# b is greater than a

# %%
name="thanishk"
age=21
print("my name is {} and age is {}".format(name,age))
# Out:
# my name is thanishk and age is 21

# %%
a=10
b=20
if(a<b):
  print("{} is greater than {}".format(b,a))
else:
  print("{} is lesser than {}".format(b,a))
# Out:
# 20 is greater than 10

# %%
a=int(input("enter a number"))
print(a)
print(type(a))
# Out:
# enter a number2
# 2
# <class 'int'>

# %%
temp=int(input("enter the temperature"))
if(temp>=25):
 print("Temp is good for paddy")
else:
  print("Temp is suitable for millets")
# Out:
# enter the temperature30
# Temp is good for paddy

# %%
a=float(input("enter the rainfall in mm"))
if(a>500):
 print("Temp is good for paddy")
else:
  print("Temp is suitable for millets")
# Out:
# enter the rainfall in mm499.999
# Temp is suitable for millets
