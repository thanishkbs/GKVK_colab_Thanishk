# %%
word="thanishk"
print(word[0])
# Out:
# t

# %%
word="thanishk"
print(word[-8])
# Out:
# t

# %%
word="thanishk"
print(word[0:5])
# Out:
# thani

# %%
name="thanishk"
print(len(name))
# Out:
# 8

# %%
text="kumar raj"
text=text.upper()
print(text)
# Out:
# KUMAR RAJ

# %%
text="kumar raj"
text=text.lower()
print(text)
# Out:
# kumar raj

# %%
text="kumar raj".title()
print(text)
# Out:
# Kumar Raj

# %%
data=" thanishk "
data.strip()
# Out:
# 'thanishk'

# %%
data=" thanishk"
data.lstrip()
# Out:
# 'thanishk'

# %%
text="i like java"
print(text.replace("java","honda"))
# Out:
# i like honda

# %%
email="user@gmail.com"
print("@"in email)
# Out:
# True

# %%
text="Python is very easy"
text=text.split()
print(text)
# Out:
# ['Python', 'is', 'very', 'easy']

# %%
words=["python" "is" "very" "easy"]
print("".join(words))
# Out:
# pythonisveryeasy

# %%
first="Python"
second="is"
third="very"
fourth="easy"
print(first+" "+second+" "+third+" "+fourth)
# Out:
# Python is very easy

# %%
name=(input("enter your name"))
age=int(input("enter your age"))
print(f"My name is {name} and age is {age}")
# Out:
# enter your namethanishk
# enter your age21
# My name is thanishk and age is 21

# %%
text="thanishk"
print(text.count("h"))
# Out:
# 2

# %%
url="https://example.com"
url.startswith("https")

file="data.csv"
file.endswith(".csv")
# Out:
# True
