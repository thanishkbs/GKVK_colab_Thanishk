# %%
num=int(input("Enter a number:"))
if num%2==0:
   print("even")
else:
  print("odd")
# Out:
# Enter a number:8
# even

# %%
age=int(input("Enter your age:"))
if age<=6:
  print("no ticket")
elif age<=12:
  print("half ticket")
else:
  print("full ticket")
# Out:
# Enter your age:11
# half ticket

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1,6):
  if i==3:
   break
  print(i)
# Out:
# 1
# 2

# %%
cgpa=int(input("enter the cgpa of the student"))
if cgpa>=8:
  print("eligible for placement")
else:
  print("not eligible for placement")
backlog=int(input("enter the number of backlogs"))
if backlog>=1:
  print("not eligible for placement")
else:
  print("eligible for placement")

semester=int(input("enter the semester number"))
if semester==8:
  print("eligible for placement")
else:
  print("not eligible for placement")
# Out:
# enter the cgpa of the student8
# eligible for placement
# enter the number of backlogs1
# not eligible for placement
# enter the semester number8
# eligible for placement

# %%
text="s" "i""r"
text= text.title()
print(text)
# Out:
# Sir

# %%
cgpa=int(input("enter the cgpa of the student"))
backlog=int(input("enter the number of backlogs"))
semester=int(input("enter the semester number"))
if cgpa>=8 and backlog<=1 and semester==8:
  print("eligible for placement")
else:
   print("not eligible for placement")
# Out:
# enter the cgpa of the student8
# enter the number of backlogs0
# enter the semester number8
# eligible for placement

# %%
cgpa=int(input("enter the cgpa of the student"))
backlog=int(input("enter the number of backlogs"))
semester=int(input("enter the semester number"))
if cgpa>=8:
  print("eligible for placement")
elif backlog<=1:
    print("eligible for placement")
elif semester==8:
      print("eligible for placement")
else:
    print("not eligible for placement")
# Out:
# enter the cgpa of the student9
# enter the number of backlogs0
# enter the semester number8
# eligible for placement

# %%
count=1
while count<=3:
 print(count)
 count+=1
# Out:
# 1
# 2
# 3
