# %%
fruits=["apple","banana","orange","tomato"]
vegetables=["brinjal","chilli","capsicum"]
print(fruits[2])
print(vegetables[2])
fruits.append("grapes")
print(fruits)
vegetables.append("beans")
print(vegetables)
fruits.remove("apple")
print(fruits)
vegetables.remove("chilli")
print(vegetables)
fruits.sort()
print(fruits)
vegetables.sort()
print(vegetables)
# Out:
# orange
# capsicum
# ['apple', 'banana', 'orange', 'tomato', 'grapes']
# ['brinjal', 'chilli', 'capsicum', 'beans']
# ['banana', 'orange', 'tomato', 'grapes']
# ['brinjal', 'capsicum', 'beans']
# ['banana', 'grapes', 'orange', 'tomato']
# ['beans', 'brinjal', 'capsicum']

# %%
students=[]
students.append("Rahul")
students.append("Ayesha")
students.append("Prakash")
print(students)

# %%
marks={
    "Math":85,
    "Science":90
}
marks["English"]=88
print(marks)
# Out:
# {'Math': 85, 'Science': 90, 'English': 88}

# %%
student={
    "name":"Prakash",
    "age":20,
    "course":"BSc(HONS)Agriculture"

}
print(student)
print(student["name"])
print(student["age"])
print(student["course"])
